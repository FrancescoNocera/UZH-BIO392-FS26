# %% [markdown]
# **Please make sure that you use "sv_env" kernel**

# %% [markdown]
# ---
# # Structural variant calling with DELLY
#
# You can install DELLY via conda
#
# `conda install delly`

# %%
# !delly -h
# Out:
# **********************************************************************
# Program: Delly
# This is free software, and you are welcome to redistribute it under
# certain conditions (BSD License); for license details use '-l'.
# This program comes with ABSOLUTELY NO WARRANTY; for details use '-w'.
#
# Delly (Version: 1.7.3)
# Contact: Tobias Rausch (rausch@embl.de)
# **********************************************************************
#
# Usage: delly <command> <arguments>
#
# Short-read SV calling:
#     call         discover and genotype structural variants
#     merge        merge structural variants across VCF/BCF files and within a single VCF/BCF file
#     filter       filter somatic or germline structural variants
#
# Long-read SV calling:
#     lr           long-read SV discovery
#
# Copy-number variant calling:
#     cnv          discover and genotype copy-number variants
#     classify     classify somatic or germline copy-number variants

# %%
# !delly call
# Out:
# Usage: delly call [OPTIONS] -g <ref.fa> <sample1.sort.bam> <sample2.sort.bam> ...
#
# Generic options:
#   -? [ --help ]                       show help message
#   -t [ --svtype ] arg (=ALL)          SV type to compute [DEL, INS, DUP, INV,
#                                       BND, ALL]
#   -g [ --genome ] arg                 genome fasta file
#   -x [ --exclude ] arg                file with regions to exclude
#   -o [ --outfile ] arg                BCF output file
#   -h [ --threads ] arg (=4)           number of threads
#
# Discovery options:
#   -q [ --map-qual ] arg (=1)          min. paired-end (PE) mapping quality
#   -r [ --qual-tra ] arg (=20)         min. PE quality for translocation
#   -s [ --mad-cutoff ] arg (=9)        insert size cutoff, median+s*MAD
#                                       (deletions only)
#   -c [ --minclip ] arg (=25)          min. clipping length
#   -z [ --min-clique-size ] arg (=2)   min. PE/SR clique size
# ...

# %%
# %cd /Users/noel/Projects/BIO392-Exercises/day_08/sample_A/
# !mkdir -p ./output/delly
# Out:
# /Users/noel/Projects/BIO392-Exercises/day_08/sample_A

# %%
# !delly call -o ./output/delly/A_dellySV.bcf \
    -g ./reference/chr14.fa \
    ./output/bqsr/A_sort_markdup_recal.bam
# Out:
# [2026-May-05 08:07:20] delly call -o ./output/delly/A_dellySV.bcf -g ./reference/chr14.fa ./output/bqsr/A_sort_markdup_recal.bam
# [2026-May-05 08:07:21] Paired-end and split-read scanning
# [2026-May-05 08:07:21] Split-read clustering
# [2026-May-05 08:07:21] Paired-end clustering
# [2026-May-05 08:07:21] Split-read assembly
# [2026-May-05 08:07:22] Generate REF and ALT probes
# [2026-May-05 08:07:22] SV annotation
# [2026-May-05 08:07:23] Genotyping
# [2026-May-05 08:07:23] Sample statistics
# Sample:A,ReadSize=101,Median=193,MAD=33,UniqueDiscordantPairs=230
# [2026-May-05 08:07:23] Done.

# %% [markdown]
# **View you SV BCF file**
#
# View only header (-h)

# %%
# !bcftools view -h ./output/delly/A_dellySV.bcf
# Out:
# ##fileformat=VCFv4.2
# ##FILTER=<ID=PASS,Description="All filters passed">
# ##fileDate=20260505
# ##ALT=<ID=DEL,Description="Deletion">
# ##ALT=<ID=DUP,Description="Duplication">
# ##ALT=<ID=INV,Description="Inversion">
# ##ALT=<ID=BND,Description="Translocation">
# ##ALT=<ID=INS,Description="Insertion">
# ##FILTER=<ID=LowQual,Description="Poor quality and insufficient number of PEs and SRs.">
# ##INFO=<ID=CIEND,Number=2,Type=Integer,Description="PE confidence interval around END">
# ##INFO=<ID=CIPOS,Number=2,Type=Integer,Description="PE confidence interval around POS">
# ##INFO=<ID=CHR2,Number=1,Type=String,Description="Chromosome for POS2 coordinate in case of an inter-chromosomal translocation">
# ##INFO=<ID=POS2,Number=1,Type=Integer,Description="Genomic position for CHR2 in case of an inter-chromosomal translocation">
# ##INFO=<ID=END,Number=1,Type=Integer,Description="End position of the structural variant">
# ...

# %% [markdown]
# View only variant (-H)

# %%
# !bcftools view -H ./output/delly/A_dellySV.bcf | head -10
# Out:
# chr14	23953632	DUP00000001	G	<DUP>	49	LowQual	IMPRECISE;SVTYPE=DUP;SVMETHOD=EMBL.DELLYv1.7.3;END=24036313;PE=2;MAPQ=25;CT=5to3;CIPOS=-58,58;CIEND=-58,58	GT:GL:GQ:FT:RCL:RC:RCR:RDCN:DR:DV:RR:RV	0/1:-0.986638,0,-59.5897:10:LowQual:239:1246:3234:1:11:2:0:0
# chr14	25267134	DEL00000002	T	<DEL>	74	LowQual	IMPRECISE;SVTYPE=DEL;SVMETHOD=EMBL.DELLYv1.7.3;END=60972300;PE=2;MAPQ=39;CT=3to5;CIPOS=-159,159;CIEND=-159,159	GT:GL:GQ:FT:RCL:RC:RCR:RDCN:DR:DV:RR:RV	0/1:-2.2825,0,-84.8827:23:PASS:86958:139198:127053:1:15:2:0:0
# chr14	104941732	DUP00000003	C	<DUP>	57	PASS	IMPRECISE;SVTYPE=DUP;SVMETHOD=EMBL.DELLYv1.7.3;END=104952162;PE=3;MAPQ=21;CT=5to3;CIPOS=-50,50;CIEND=-50,50	GT:GL:GQ:FT:RCL:RC:RCR:RDCN:DR:DV:RR:RV	0/0:0,-35.8482,-791.806:10000:PASS:983:9561:1805:7:137:4:0:0
# ...

# %% [markdown]
# ---
# **CNV calling**
#
# This process require Mappability map file.
#
# You can get it from here : https://gear-genomics.embl.de/data/delly/
#
# **Notes**
#
# We cannot demon running CNV call wiht our trim dataset
# So, The command below is just an example

# %%
"""
# !printf "chr22\t19720000 \t19730000\n" > ./db/delly/focus_region.bed
"""

# %%
""""
# !delly cnv -o ./output/delly/A_dellyCNV.bcf \
    -g ./reference_chr22/hg38_GRCh38.chr22.fa \
    -l ./output/delly/A_dellySV.bcf \
    -m ./db/delly/chr22.blacklist.fa.gz \
    -c ./output/delly/A_cov.gz \
    -r ./db/delly/focus_region.bed \
    ./output/bqsr/A_sort_markdup_recal.bam
"""

# %% [markdown]
# ---
# ### SV filtering with vcftools

# %%
# !bcftools view -f PASS \
    -e 'INFO/IMPRECISE=1' \
    ./output/delly/A_dellySV.bcf \
    -o ./output/delly/A_dellySV_filter.bcf

# %% [markdown]
# **View BCF file**

# %%
# !bcftools view -H ./output/delly/A_dellySV.bcf
# Out:
# chr14	23953632	DUP00000001	G	<DUP>	49	LowQual	IMPRECISE;SVTYPE=DUP;SVMETHOD=EMBL.DELLYv1.7.3;END=24036313;PE=2;MAPQ=25;CT=5to3;CIPOS=-58,58;CIEND=-58,58	GT:GL:GQ:FT:RCL:RC:RCR:RDCN:DR:DV:RR:RV	0/1:-0.986638,0,-59.5897:10:LowQual:239:1246:3234:1:11:2:0:0
# chr14	25267134	DEL00000002	T	<DEL>	74	LowQual	IMPRECISE;SVTYPE=DEL;SVMETHOD=EMBL.DELLYv1.7.3;END=60972300;PE=2;MAPQ=39;CT=3to5;CIPOS=-159,159;CIEND=-159,159	GT:GL:GQ:FT:RCL:RC:RCR:RDCN:DR:DV:RR:RV	0/1:-2.2825,0,-84.8827:23:PASS:86958:139198:127053:1:15:2:0:0
# chr14	104941732	DUP00000003	C	<DUP>	57	PASS	IMPRECISE;SVTYPE=DUP;SVMETHOD=EMBL.DELLYv1.7.3;END=104952162;PE=3;MAPQ=21;CT=5to3;CIPOS=-50,50;CIEND=-50,50	GT:GL:GQ:FT:RCL:RC:RCR:RDCN:DR:DV:RR:RV	0/0:0,-35.8482,-791.806:10000:PASS:983:9561:1805:7:137:4:0:0
# ...

# %%
# !bcftools view -H ./output/delly/A_dellySV_filter.bcf

# %% [markdown]
# ---
