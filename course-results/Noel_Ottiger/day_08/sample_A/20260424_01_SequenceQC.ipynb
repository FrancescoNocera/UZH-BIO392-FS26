# %% [markdown]
# **Please make sure that you use "human_env" kernel**
#
#
# ------------------------------------------------------------

# %% [markdown]
# # FastQC
# A quality control tool for high throughput sequence data.
#
# https://www.bioinformatics.babraham.ac.uk/projects/fastqc/
#
#
# You can install FastQC via conda on Python 3.x
#
# `conda activate human_env`
#
# `conda install -c bioconda -y fastqc`
#
# Basic command syntax : Check version
#
# `fastqc --version`

# %%
import os
os.environ["JAVA_HOME"] = "/Users/noel/miniconda3/envs/bio392/lib/jvm"
os.environ["PATH"] = os.path.join(os.environ["JAVA_HOME"], "bin") + ":" + os.environ["PATH"]

# !fastqc --version
# Out:
# FastQC v0.12.1

# %% [markdown]
# Show Howto and parameters

# %%
# !fastqc --help
# Out:
#             FastQC - A high throughput sequence QC analysis tool
#
# SYNOPSIS
#
# 	fastqc seqfile1 seqfile2 .. seqfileN
#
#     fastqc [-o output dir] [--(no)extract] [-f fastq|bam|sam]
#            [-c contaminant file] seqfile1 .. seqfileN
#
# DESCRIPTION
#
#     FastQC reads a set of sequence files and produces from each one a quality
#     control report consisting of a number of different modules, each one of
#     which will help to identify a different potential type of problem in your
#     data.
#
#     If no files to process are specified on the command line then the program
#     will start as an interactive graphical application.  If files are provided
#     on the command line then the program will run with no user interaction
#     required.  In this mode it is suitable for inclusion into a standardised
#     analysis pipeline.
#
#     The options for the program as as follows:
#
#     -h --help       Print this help file and exit
#
# ...

# %% [markdown]
# Check current working directory

# %%
# !pwd
# Out:
# /Users/noel/Projects/BIO392-Exercises/day_08/sample_A

# %% [markdown]
# Change directory to where the fastq files are located

# %%
# %cd ./data/FASTQ_Chr14
# Out:
# /Users/noel/Projects/BIO392-Exercises/day_08/sample_A/data/FASTQ_Chr14

# %% [markdown]
# Create directory for store output file.

# %%
# !mkdir -p ./output/FastQC_Out

# %%
# !fastqc -f fastq -t 2 -o ./output/FastQC_Out A_1.fq.gz A_2.fq.gz
# Out:
# application/gzip
# application/gzip
# Started analysis of A_1.fq.gz
# Approx 5% complete for A_1.fq.gz
# Approx 10% complete for A_1.fq.gz
# Started analysis of A_2.fq.gz
# Approx 15% complete for A_1.fq.gz
# Approx 5% complete for A_2.fq.gz
# Approx 20% complete for A_1.fq.gz
# Approx 10% complete for A_2.fq.gz
# Approx 25% complete for A_1.fq.gz
# Approx 15% complete for A_2.fq.gz
# Approx 30% complete for A_1.fq.gz
# Approx 20% complete for A_2.fq.gz
# Approx 35% complete for A_1.fq.gz
# Approx 25% complete for A_2.fq.gz
# Approx 40% complete for A_1.fq.gz
# Approx 30% complete for A_2.fq.gz
# Approx 45% complete for A_1.fq.gz
# Approx 35% complete for A_2.fq.gz
# Approx 50% complete for A_1.fq.gz
# Approx 40% complete for A_2.fq.gz
# Approx 55% complete for A_1.fq.gz
# Approx 45% complete for A_2.fq.gz
# Approx 60% complete for A_1.fq.gz
# Approx 50% complete for A_2.fq.gz
# Approx 65% complete for A_1.fq.gz
# Approx 55% complete for A_2.fq.gz
# Approx 70% complete for A_1.fq.gz
# ...

# %%
# !pwd
# %cd ./output/FastQC_Out
# Out:
# /Users/noel/Projects/BIO392-Exercises/day_08/sample_A/data/FASTQ_Chr14
# /Users/noel/Projects/BIO392-Exercises/day_08/sample_A/data/FASTQ_Chr14/output/FastQC_Out

# %%
# !ls
# Out:
# A_1_fastqc      A_1_fastqc.html A_1_fastqc.zip  A_2_fastqc.html A_2_fastqc.zip

# %% [markdown]
# You can unzip the zip file to get access to raw data.

# %%
# !unzip A_1_fastqc.zip
# Out:
# Archive:  A_1_fastqc.zip
#    creating: A_1_fastqc
#    creating: A_1_fastqc/Icons
#    creating: A_1_fastqc/Images
#   inflating: A_1_fastqc/Icons/fastqc_icon.png
#   inflating: A_1_fastqc/Icons/warning.png
#   inflating: A_1_fastqc/Icons/error.png
#   inflating: A_1_fastqc/Icons/tick.png
#   inflating: A_1_fastqc/summary.txt
#   inflating: A_1_fastqc/Images/per_base_quality.svg
#   inflating: A_1_fastqc/Images/per_base_quality.png
#   inflating: A_1_fastqc/Images/per_tile_quality.svg
#   inflating: A_1_fastqc/Images/per_tile_quality.png
#   inflating: A_1_fastqc/Images/per_sequence_quality.svg
#   inflating: A_1_fastqc/Images/per_sequence_quality.png
#   inflating: A_1_fastqc/Images/per_base_sequence_content.svg
#   inflating: A_1_fastqc/Images/per_base_sequence_content.png
#   inflating: A_1_fastqc/Images/per_sequence_gc_content.svg
#   inflating: A_1_fastqc/Images/per_sequence_gc_content.png
#   inflating: A_1_fastqc/Images/per_base_n_content.svg
# ...

# %% [markdown]
# **Finished**

# %% [markdown]
# ------------------------------------------------------------
# # fastp
# A tool designed to provide ultrafast all-in-one preprocessing and quality control for FastQ data.
#
# https://github.com/opengene/fastp
#
#
# You can install fastp via conda
#
# `conda activate human_env`
#
# `conda install fastp`
#
# Basic command syntax : Check version
#
# `fastp --version`
#
# -----------------------------------------------------------

# %% [markdown]
# **For execute Unix/Linux command in Jupyter notebook, please put "!" infront of the command.**

# %% [markdown]
# Show Howto and parameters

# %% [markdown]
# **For execute Unix/Linux command in Jupyter notebook, please put "!" infront of the command.**

# %% [markdown]
# Show Howto and parameters

# %%
# !fastp --version
# Out:
# fastp 1.3.3

# %%
# !fastp --help
# Out:
# usage: fastp [options] ...
# options:
#   -i, --in1                            read1 input file name (string [=])
#   -o, --out1                           read1 output file name (string [=])
#   -I, --in2                            read2 input file name (string [=])
#   -O, --out2                           read2 output file name (string [=])
#       --unpaired1                      for PE input, if read1 passed QC but read2 not, it will be written to unpaired1. Default is to discard it. (string [=])
#       --unpaired2                      for PE input, if read2 passed QC but read1 not, it will be written to unpaired2. If --unpaired2 is same as --unpaired1 (default mode), both unpaired reads will be written to this same file. (string [=])
#       --overlapped_out                 for each read pair, output the overlapped region if it has no any mismatched base. (string [=])
# ...

# %%
# %cd /Users/noel/Projects/BIO392-Exercises/day_08/sample_A/
# !mkdir -p ./output/fastp
# Out:
# /Users/noel/Projects/BIO392-Exercises/day_08/sample_A

# %%
# !fastp -i ./data/FASTQ_Chr14/A_1.fq.gz \
    -I ./data/FASTQ_Chr14/A_2.fq.gz \
    -o ./output/fastp/clean_A_1.fq.gz \
    -O ./output/fastp/clean_A_2.fq.gz \
    -q 30 \
    -h ./output/fastp/A_fastp_report.html
# Out:
# Read1 before filtering:
# total reads: 515482
# total bases: 52063682
# Q20 bases: 51576063(99.0634%)
# Q30 bases: 50029094(96.0921%)
# Q40 bases: 18901203(36.304%)
#
# Read2 before filtering:
# total reads: 515482
# total bases: 52063682
# Q20 bases: 51364266(98.6566%)
# Q30 bases: 49633705(95.3327%)
# Q40 bases: 18624700(35.7729%)
#
# Read1 after filtering:
# total reads: 502243
# total bases: 50716567
# Q20 bases: 50461423(99.4969%)
# Q30 bases: 49178716(96.9678%)
# Q40 bases: 18785009(37.0392%)
#
# Read2 after filtering:
# total reads: 502243
# total bases: 50716567
# Q20 bases: 50351263(99.2797%)
# Q30 bases: 48877450(96.3737%)
# Q40 bases: 18538114(36.5524%)
#
# Filtering result:
# reads passed filter: 1004486
# reads failed due to low quality: 26408
# reads failed due to too many N: 70
# reads failed due to too short: 0
# reads failed due to adapter dimer: 0
# reads with adapter trimmed: 1056
# bases trimmed due to adapters: 20224
#
# Duplication rate: 0%
#
# ...

# %% [markdown]
# **Finished**
